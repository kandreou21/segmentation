# %%
import torch
import torchvision
from torchvision import transforms
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import cv2
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from collections import OrderedDict
from diptest import diptest
from scipy.sparse import lil_matrix
import networkx as nx


model = torchvision.models.segmentation.deeplabv3_resnet101(weights='DeepLabV3_ResNet101_Weights.DEFAULT') 
model.eval() #sets model in evaluation mode

filename = "low-resolution/car.jpg"
input_image = Image.open(filename)
scale_percent = 0.5
input_image = input_image.resize((int(input_image.width*scale_percent), int(input_image.height*scale_percent))) # Resize for large images
input_image = input_image.convert("RGB")

W, H = input_image.size
print("Input image dimensions:", H, W)

# %%
# The images have to be loaded in to a range of [0, 1] and then normalized using the following mean and std 
preprocess = transforms.Compose([ 
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
input_tensor = preprocess(input_image)
input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model(adds 1 more dimension to tensor)

# move the input and model to GPU for speed if available
if torch.cuda.is_available():
    input_batch = input_batch.to('cuda')
    model.to('cuda')

with torch.no_grad(): 
    output = model(input_batch)['out'][0]
output_predictions = output.argmax(0)  # To get the maximum prediction of each class

# %%
# create a color pallette, selecting a color for each class
def get_colors():
    palette = torch.tensor([np.random.randint(0, 256), np.random.randint(0, 256), np.random.randint(0, 256)])
    colors = torch.as_tensor([i for i in range(50)])[:, None] * palette
    colors = (colors % 255).numpy().astype("uint8")
    
    return colors


def image_overlay(image, segmented_image):
    alpha = 1   # transparency for the original image
    beta = 0.8  # transparency for the segmentation map
    gamma = 0   # scalar added to each sum

    image = np.array(image)
    if isinstance(segmented_image, Image.Image):
        segmented_image = segmented_image.convert("RGB")
        segmented_image = np.array(segmented_image)

    cv2.addWeighted(image, alpha, segmented_image, beta, gamma, image)
    
    return image

random_colors = get_colors()
six_colors = [[255, 0, 0], [0, 255, 0], [0, 0, 255], [255, 255, 0], [255, 0, 255], [0, 255, 255]] 

# plot the semantic segmentation predictions of 21 classes in each color
deeplab_segmented_image = Image.fromarray(output_predictions.byte().cpu().numpy()).resize(input_image.size)
deeplab_segmented_image.putpalette(random_colors)
overlayed_deeplab_image = image_overlay(input_image, deeplab_segmented_image)

plt.subplot(1, 3, 1)
plt.imshow(input_image)
plt.subplot(1, 3, 2)
plt.imshow(deeplab_segmented_image)
plt.subplot(1, 3, 3)
plt.imshow(overlayed_deeplab_image)
plt.show()

# %%
# retrieving aspp layer features 
def get_aspp_features():
    aspp = torchvision.models.segmentation.deeplabv3.ASPP(in_channels=3, atrous_rates=[6, 12, 18])
    aspp.eval()

    aspp_features = aspp.forward(input_batch)
    return aspp_features.squeeze(0)

aspp_features = get_aspp_features()
display(aspp_features.shape)
# Out:
# torch.Size([256, 160, 240])

# %%
# Applying PCA to ASPP features
def apply_pca_on_aspp(n_components):
    features = aspp_features.detach().numpy() # Convert to numpy array
    reshaped_aspp = features.reshape(256, features.shape[1]*features.shape[2])  # Reshape to [256, HEIGHT * WIDTH] (pca is applied to 2d data)
    pca = PCA(n_components=n_components)
    principalComponents = pca.fit_transform(reshaped_aspp.T).T # Transpose for the correct shape
    pca_features = principalComponents.reshape(n_components, *features.shape[1:]) 
    
    return pca_features

n_components = 2
pca_features = apply_pca_on_aspp(n_components)
display(pca_features.shape)
# Out:
# (2, 160, 240)

# %%
# Convert original image to LAB color space
def convert_lab():
    input = cv2.imread(filename)
    input = cv2.resize(input, (int(input.shape[1]*scale_percent), int(input.shape[0]*scale_percent)))
    lab_image = cv2.cvtColor(input, cv2.COLOR_BGR2LAB)
    lab_image = np.transpose(lab_image, (2, 0, 1))
    
    return lab_image

lab_image = convert_lab()
display(lab_image.shape)

pca_lab_sum = np.concatenate((pca_features, lab_image), axis=0)
display(pca_lab_sum.shape)
# Out:
# (3, 160, 240)
# (5, 160, 240)

# %%
# Check if any object was recognised
def has_objects():
    return (output_predictions != 0).any()


# Updates if no object was recognised
def update_no_objects_found(new_pca_lab_sum):
    w = 0.2
    new_pca_lab_sum[:n_components] = pca_lab_sum[:n_components] * w
    new_pca_lab_sum[n_components:] = pca_lab_sum[n_components:] * (1-w)


# Updates if at least one object was recognised
def update_objects_found(new_pca_lab_sum):
    w = 0.1
    for i in range(output_predictions.shape[0]):
        for j in range(output_predictions.shape[1]):
            if output_predictions[i][j] == 0:
                new_pca_lab_sum[:n_components, i , j] = pca_lab_sum[:n_components, i, j] * w
                new_pca_lab_sum[n_components:, i , j] = pca_lab_sum[n_components:, i, j] * (1-w)
            else:
                new_pca_lab_sum[:, i , j] = 0
                #new_pca_lab_sum[:n_components, i , j] = pca_lab_sum[:n_components, i, j] * (1-w)
                #new_pca_lab_sum[n_components:, i , j] = pca_lab_sum[n_components:, i, j] * w

print("Object found = ", has_objects())
new_pca_lab_sum = np.zeros(pca_lab_sum.shape, dtype=np.float32)

if has_objects() == False:
    update_no_objects_found(new_pca_lab_sum)
else:
    update_objects_found(new_pca_lab_sum)

def print_updates():
    for i in range(new_pca_lab_sum.shape[0]):
        for j in range(new_pca_lab_sum.shape[1]):
            for k in range(new_pca_lab_sum.shape[2]):
                print(new_pca_lab_sum[i, j, k])


def add_spatial_info(new_pca_lab_sum):
    new_sum = np.zeros((H*W, 7), dtype=np.float32)
    for y in range(H):
        for x in range(W):
            pixel_index = y * W + x
            new_sum[pixel_index, 0:5] = new_pca_lab_sum[:, y, x]
            new_sum[pixel_index, 5] = x  
            new_sum[pixel_index, 6] = y
    return new_sum

pca_lab_spatial = add_spatial_info(new_pca_lab_sum)
#print_updates()
# Out:
# Object found =  tensor(False)

# %%
# Clustering
# Global k-means++
class Global_Kmeans_pp():
	def __init__(self, n_clusters=2, n_init=100, max_iter=300, tol=1e-4, verbose=1):
		self.n_clusters = n_clusters
		self.n_init = n_init
		self.max_iter = max_iter
		self.tol = tol
		self.verbose = verbose
		self.cluster_centers_ = OrderedDict()
		self.cluster_distance_space_ = OrderedDict()
		self.inertia_ = OrderedDict()
		self.labels_ = OrderedDict()

	def fit(self, X, y=None):
		kmeans = KMeans(n_clusters=1, init='random', n_init=1, tol=self.tol).fit(X)
		self.n_data = X.shape[0]
		self.cluster_centers_[1] = kmeans.cluster_centers_
		self.cluster_distance_space_[1] = kmeans.transform(X).min(axis=1)
		self.labels_[1] = kmeans.labels_
		self.inertia_[1] = kmeans.inertia_

		k = 1
		while True:
			if k < self.n_clusters:
				k += 1

				if 0 < self.verbose: print('Solving {:d}-means'.format(k))
				centroid_candidates, _ = self.__kmeans_pp(X, self.cluster_distance_space_[k-1])

				self.inertia_[k] = float('inf')
				for i, xi in enumerate(centroid_candidates): # TODO parallel
					current_centroids = np.vstack((self.cluster_centers_[k-1], xi))
					kmeans = KMeans(n_clusters=k, init=current_centroids, n_init=1, tol=self.tol)
					kmeans = kmeans.fit(X)

					if kmeans.inertia_ < self.inertia_[k]:
						self.cluster_centers_[k] = kmeans.cluster_centers_
						self.labels_[k] = kmeans.labels_
						self.inertia_[k] = kmeans.inertia_
						self.cluster_distance_space_[k] = kmeans.transform(X).min(axis=1)
			else:
				break

		return self

	def predict(self, X):
		return self.labels_, self.cluster_centers_, self.inertia_

	def transform(self, X):
		return self.cluster_distance_space_

	def __kmeans_pp(self, X, cluster_distance_space):
		cluster_distance_space = np.power(cluster_distance_space, 2).flatten()
		sum_distance = np.sum(cluster_distance_space)
		selection_prob = cluster_distance_space / sum_distance
		selected_indexes = np.random.choice(self.n_data, size=self.n_init, p=selection_prob, replace=False)
		kmeans_pp_selected_centroids = X[selected_indexes]
		return kmeans_pp_selected_centroids, selected_indexes

# %%
# Unimodality Testing
def pca_split(X, ci, cj, alpha):
	pca = PCA(n_components = 1)
	projection = pca.fit_transform(X)
	projection = np.reshape(projection, (projection.shape[0],))
	dip, pval = diptest(projection)
	condition = pval < alpha
	return condition

def axis_split(X, c_i, c_j, alpha):
	w = c_j - c_i
	b = - np.dot(c_i, c_i)
	unnormalized_algebraic_distances_to_hyperplane = np.dot(X, w) + b
	dip, pval = diptest(unnormalized_algebraic_distances_to_hyperplane, boot_pval=False)
	condition = pval < alpha
	return condition

# %%
# Utilities
class UnionFind:
	def __init__(self, elements):
		self.size_ = len(elements) # number of trees
		self.data_structure_ = [i for i in range(self.size_)]
		self.sizes_ = [1 for i in range(self.size_)] # sizes of trees
		self.element_ = elements # index to element
		self.index_ = {element: index for index, element in enumerate(elements)} # element to index

	def union(self, element_1, element_2):
		root_1_index = self.index_[self.find(element_1)]
		root_2_index = self.index_[self.find(element_2)]

		size_1 = self.sizes_[root_1_index]
		size_2 = self.sizes_[root_2_index]
		union_size = size_1 + size_2

		# connecting the two trees
		if size_1 <= size_2:
			self.data_structure_[root_2_index] = root_1_index
		else:
			self.data_structure_[root_1_index] = root_2_index

		self.sizes_[root_1_index] = self.sizes_[root_2_index] = union_size
		self.size_ -= 1

	def find(self, element):
		index = self.index_[element]
		path_indices = []
		while self.data_structure_[index] != index:
			path_indices.append(index)
			index = self.data_structure_[index]
		root_index = index

		# shortening the tree
		for index in path_indices:
			self.data_structure_[index] = root_index

		return self.element_[root_index]

	def to_list(self):
		# turning all trees into stars
		for element in self.element_:
			self.find(element)

		list_of_lists = [[] for i in range(len(self.element_))]
		for index, element in enumerate(self.element_):
			list_of_lists[self.data_structure_[index]].append(element)
		return [_list for _list in list_of_lists if len(_list) > 0]
	
def cc_index(cc_list, node):
	for i, cc in enumerate(cc_list):
		if node in cc:
			return i
	return None

# %%
# UniForCE method
#cluster_centers1 = np.zeros((0, 0), dtype=np.float64)
flag = False
labels_to_feed = np.zeros((0, 0), dtype=np.uint8)
cluster_centers2 = np.zeros((0, 0), dtype=np.float64)

def overclustering(data, options):
	global cluster_centers1
	if (flag == True):
		print("passed through here, flag=True")
		#print("LABELS TO FEED: ", np.unique(labels_to_feed, return_counts=True)[1])
		#print("CLUSTER CENTERS2: ", np.unique(cluster_centers2, return_counts=True)[1])
		return labels_to_feed, cluster_centers2[:, :cluster_centers2.shape[1]-2]
	elif np.isscalar(options['n_subclusters']):
		print("passed through here 1")
		if options['algorithm'] == 'globalkmeans++':
			print("passed through here 1.1")
			selected_model = Global_Kmeans_pp(n_clusters = options['n_subclusters'], n_init = 10).fit(data)
			return selected_model.labels_[selected_model.n_clusters], selected_model.cluster_centers_[selected_model.n_clusters]
		else:
			print("passed through here 1.2")
			model = {
				'kmeans++': KMeans(n_clusters = options['n_subclusters'], n_init = 10)
			}
			selected_model = model[options['algorithm']].fit(data)
			#cluster_centers1 = selected_model.cluster_centers_ # apo edw pernaei, cluster_centers attribute tou KMeans
			#print("1o ", cluster_centers1)
			return selected_model.labels_, selected_model.cluster_centers_
	else:
		print("passed through here 2")
		if options['algorithm'] == 'globalkmeans++':
			selected_model = Global_Kmeans_pp(n_clusters = np.max(options['n_subclusters']), n_init = 10).fit(data)
			return selected_model.labels_, selected_model.cluster_centers_
		else:
			labels = {}
			cluster_centers = {}
			for K in options['n_subclusters']:
				model = {
					'kmeans++': KMeans(n_clusters = K, n_init = 10)
				}
				selected_model = model[options['algorithm']].fit(data)
				labels[K] = selected_model.labels_
				cluster_centers[K] = selected_model.cluster_centers_
			return labels, cluster_centers

def in_same_tree(uf, i, j):
	for this_set in uf.to_sets():
		if i in this_set and j in this_set:
			return True
	return False

def kruskal(data, subpredictions, subcluster_centers, options): # Kruskal's algorithm finds a minimum spanning forest of an undirected edge-weighted graph
	n_clusters = options['n_clusters']
	n_subclusters = options['n_subclusters']
	min_size = options['min_size']
	distribution = options['distribution']
	alpha = options['alpha']
	n_tests = options['n_tests']

	unimodality_test = {'default': axis_split, 'pca': pca_split}

	adjacency_matrix = lil_matrix(np.zeros([n_subclusters, n_subclusters], dtype=float))
	index_map = {tuple(subcluster_centers[i].tolist()): i for i in range(n_subclusters)}

	#print("SUBPREDICTIONS: ", np.unique(subpredictions))
	subcluster_sizes = np.unique(subpredictions, return_counts=True)[1]
	#print("SUBCLUSTER SIZES: ", subcluster_sizes)
	is_active = (subcluster_sizes >= min_size)
	active_subclusters = np.nonzero(is_active)[0]
	union_find = nx.utils.UnionFind(active_subclusters)

	edges = [(tuple(subcluster_centers[i].tolist()), tuple(subcluster_centers[j].tolist())) for i in active_subclusters for j in active_subclusters if i < j]

	# Sorting edges by their length in
	edges = sorted(edges, key = lambda edge: (edge[0][0] - edge[1][0])**2 + (edge[0][1] - edge[1][1])**2)

	# reassigning inactive subcluster samples
	is_inactive = (subcluster_sizes < min_size)
	inactive_subclusters = np.nonzero(is_inactive)[0]
	remaining_samples_indices = np.nonzero(np.isin(subpredictions, inactive_subclusters))[0]
	if remaining_samples_indices.shape[0] > 0:
		subpredictions[remaining_samples_indices] = active_subclusters[np.argmin(euclidean_distances(data[remaining_samples_indices], subcluster_centers[active_subclusters]), axis = 1)]

	# recalculating subcluster centers
	#print("SUBCLUSTER_SIZES= ", len(subcluster_sizes))
	for j in range(len(subcluster_sizes)): # in range(n_subclusters) prin, alla n_subclusters=30 kai subpredictions.size == 3=clusters tou protou run
		if is_active[j]:
			subcluster_centers[j, :] = np.average(data[np.where(subpredictions == j)[0]], axis = 0) 

	for edge in edges:
		i = index_map[edge[0]]
		j = index_map[edge[1]]
		if not in_same_tree(union_find, i, j):

			# Samples of subclusters i and j
			samples_indexes_i = np.where(subpredictions==i)[0]
			samples_indexes_j = np.where(subpredictions==j)[0]
			samples_indexes = np.concatenate((samples_indexes_i, samples_indexes_j))
			X, y = data[samples_indexes], subpredictions[samples_indexes]

			# Sorting subclusters by sample size
			n_i = samples_indexes_i.shape[0]
			n_j = samples_indexes_j.shape[0]
			if n_j < n_i:
				temp = samples_indexes_i
				samples_indexes_i = samples_indexes_j
				samples_indexes_j = temp

				temp = n_i
				n_i = n_j
				n_j = temp

				temp = i
				i = j
				j = temp

			# Performing odd number unimodality tests
			for ii in range(n_tests):
				sub_indexes = np.random.choice(n_j, size=n_i, replace=False)
				samples_indexes = np.concatenate((samples_indexes_i, samples_indexes_j[sub_indexes]))
				X, y = data[samples_indexes], subpredictions[samples_indexes]
				if unimodality_test[distribution](X, subcluster_centers[i], subcluster_centers[j], alpha):
					adjacency_matrix[i, j] -= 1
				else:
					adjacency_matrix[i, j] += 1
			adjacency_matrix[j, i] = adjacency_matrix[i, j]
			if adjacency_matrix[i, j] > 0:
				union_find.union(i, j)

		# early termination if target number of clusters was reached
		if (n_clusters is not None) and (len([cluster for cluster in union_find.to_sets()]) <= n_clusters):
			break

	clusters = [cluster for cluster in union_find.to_sets()]
	predictions = np.array([cc_index(clusters, subpredictions[i]) for i in range(data.shape[0])])

	return predictions, subpredictions, subcluster_centers, is_active, adjacency_matrix.toarray(), clusters

def kruskal_plus_plus(data, options):
	n_subclusters = options['n_subclusters']
	alpha = options['alpha']
	max_iter = options['max_iter']
	options['n_subclusters'] = n_subclusters
	sublabels, subcluster_centers = overclustering(data, options)
	n_subclusters = subcluster_centers.shape[0]
	options['n_subclusters'] = n_subclusters
	labels, sublabels, subcluster_centers, is_active, adjacency_matrix, clusters = kruskal(data, sublabels, subcluster_centers, options)

	return labels, sublabels, subcluster_centers, is_active, adjacency_matrix, clusters

class UniForCE:
	default_options_ = {
		'algorithm': 'globalkmeans++', # clustering algorithm for initial overclustering from {'kmeans++', 'globalkmeans++'}
		'n_clusters': None, # number of desired clusters
		'n_subclusters': 50, # number of overclustering clusters
		'stat_test': 'diptest', # statistical test for unimodality testing
		'distribution': 'default', # distribution to be tested for unimodality from {'default', 'pca'}
		'min_size': 25, # minimum subcluster size (required for statistical test validity)
		'n_tests': 11, # number of tests on subsampled clusters
		'alpha': 1e-3, # confidence interval
		'max_iter': 1, # maximum number of overclustering iterations
	}

	def __init__(self, options):
		self.options_ = self.default_options_
		for key in options.keys():
			self.options_[key] = options[key]

	def fit(self, X, y = None):
		if np.isscalar(self.options_['n_subclusters']):
			self.labels_, self.sublabels_, self.subcluster_centers_, self.is_active_, self.adjacency_, self.clusters_ = kruskal_plus_plus(X, self.options_)
			self.n_clusters_ = len(self.clusters_)
			self.n_subclusters_ = self.subcluster_centers_.shape[0]
		else:
			self.labels_ = {}
			self.sublabels_, self.subcluster_centers_ = overclustering(X, self.options_)
			self.is_active_ = {}
			self.adjacency_ = {}
			self.clusters_ = {}
			self.n_clusters_ = {}
			self.n_subclusters_ = {}
			options = dict(self.options_)
			for K in self.options_['n_subclusters']:
				options['n_subclusters'] = K
				self.labels_[K], self.sublabels_[K], self.subcluster_centers_[K], self.is_active_[K], self.adjacency_[K], self.clusters_[K] = kruskal(X, self.sublabels_[K], self.subcluster_centers_[K], options)
				self.n_clusters_[K] = len(self.clusters_[K])
				self.n_subclusters_[K] = self.subcluster_centers_[K].shape[0]
		return self

# %%
# Silhouette score for ideal n_clusters using kmeans
k = [2, 3, 4, 5, 6]
d2_new_pca_lab_sum = new_pca_lab_sum.reshape(new_pca_lab_sum.shape[0], new_pca_lab_sum.shape[1] * new_pca_lab_sum.shape[2]).T
display(d2_new_pca_lab_sum.shape)
# Randomly sample a subset of points
sampled_data = d2_new_pca_lab_sum[np.random.choice(d2_new_pca_lab_sum.shape[0], size=d2_new_pca_lab_sum.shape[0]//10, replace=False)]
#sampled_data = d2_new_pca_lab_sum
display(sampled_data.shape)
best_silhouette_score = -1
best_k = 0

for n_clusters in k:
    km = KMeans(n_clusters=n_clusters, n_init="auto") 
    labels = km.fit_predict(sampled_data)

    score = silhouette_score(sampled_data, labels) 
    print("For n_clusters = {}, silhouette score is {})".format(n_clusters, score))
    
    # Update best k if the silhouette score is higher
    if score > best_silhouette_score:
        best_silhouette_score = score
        best_k = n_clusters

print(f"The best k is {best_k} with a silhouette score of {best_silhouette_score}")
# Out:
# (38400, 5)
# (3840, 5)
# For n_clusters = 2, silhouette score is 0.3990907669067383)
# For n_clusters = 3, silhouette score is 0.49248936772346497)
# For n_clusters = 4, silhouette score is 0.47621434926986694)
# For n_clusters = 5, silhouette score is 0.4795916974544525)
# For n_clusters = 6, silhouette score is 0.45674648880958557)
# The best k is 3 with a silhouette score of 0.49248936772346497

# %%
# Segmentation using Uniforce on PCA ASPP&LAB features
options = {
		'algorithm': 'globalkmeans++', # clustering algorithm for initial overclustering from {'kmeans++', 'globalkmeans++'}
		'n_clusters': None, # number of desired clusters (default is None)
		'n_subclusters': 30, # number of overclustering clusters 
		'min_size': 10, # minimum subcluster size (required for statistical test validity) # DOKIMI KAI ME 25
		'distribution': 'default', # distribution to be tested for unimodality from {'default', 'pca'}
		'alpha': 1e-5, # confidence interval, max value 5e-2, 1e-2, 1e-3
		'n_tests': 11, # number of tests on subsampled clusters
		'max_iter': 1, # maximum number of overclustering iterations
	}

def extract_labels_info(clustering_method):
    labels = clustering_method.labels_
    unique_labels = np.unique(labels)

    num_clusters = unique_labels.size
    print("number of clusters=", num_clusters)
    return labels, unique_labels, num_clusters


def color_segmented_image(labels, unique_labels, colors):
	segmented_image = np.zeros((H, W, 3), dtype=np.uint8)
	labels = labels.reshape((H, W))
	for i, label in enumerate(unique_labels):
		mask = labels == label
		segmented_image[mask] = colors[i]
	return segmented_image


def calculate_centroids(data, labels):
    unique_labels = np.unique(labels)
    centroids = []
    #data = data[:, 0:3]
    for label in unique_labels:
        cluster_points = data[labels == label][0:3] # Find points belonging to the current cluster
        centroid = np.mean(cluster_points, axis=0)
        centroids.append(centroid)
    return np.array(centroids)

# Uniforce on input rgb image
rgb_image = cv2.cvtColor(cv2.imread(filename), cv2.COLOR_BGR2RGB)
rgb_image = cv2.resize(rgb_image, (int(rgb_image.shape[1]*scale_percent), int(rgb_image.shape[0]*scale_percent)))
rgb_pixels = rgb_image.reshape((rgb_image.shape[0]*rgb_image.shape[1],3))

rgb_xy = np.zeros((H*W, 5), dtype=np.uint16)
for y in range(H):
    for x in range(W):
        pixel_index = y * W + x
        rgb_xy[pixel_index, 0:3] = rgb_image[y, x]
        rgb_xy[pixel_index, 3] = x
        rgb_xy[pixel_index, 4] = y

def uniforce_RGB():
    global labels_to_feed
    global cluster_centers2
    global flag
    scaler = MinMaxScaler()
    rgb_pixels_scaled = scaler.fit_transform(rgb_xy)
    uniforce = UniForCE(options)
    uniforce.fit(rgb_pixels_scaled)
    labels_to_feed = uniforce.labels_
    cluster_centers2 = calculate_centroids(rgb_pixels_scaled, labels_to_feed)
    flag = True
    #print("1o ", cluster_centers1)
    #print("2o ", cluster_centers2) 
    # uniforce.subcluster_centers_ == selected_model.cluster_centers_
    
    _, unique_labels, rgbxy_clusters = extract_labels_info(uniforce)
    uniforce_rgbxy_image = color_segmented_image(labels_to_feed, unique_labels, random_colors)
    
    return rgbxy_clusters, uniforce_rgbxy_image

rgbxy_clusters, uniforce_rgbxy_image = uniforce_RGB()

def uniforce_RGB_second_run():
    global flag
    scaler = MinMaxScaler()
    rgb_pixels_scaled = scaler.fit_transform(rgb_pixels)
    uniforce = UniForCE(options)
    uniforce.fit(rgb_pixels_scaled)

    labels, unique_labels, rgb_clusters = extract_labels_info(uniforce)
    uniforce_rgb_image = color_segmented_image(labels, unique_labels, random_colors)
    
    plt.imshow(uniforce_rgb_image)
    plt.show()
    #print("2o labels: ", np.unique(uniforce.labels_, return_counts=True)[1])
    #print("2o cluster_centers: ", np.unique(uniforce.subcluster_centers_, return_counts=True)[1])
    flag = False
    return rgb_clusters, uniforce_rgb_image

new_rgb_clusters, new_uniforce_rgb_image = uniforce_RGB_second_run()
# Out:
# passed through here 1
# passed through here 1.1
# Solving 2-means
# Solving 3-means
# Solving 4-means
# Solving 5-means
# Solving 6-means
# Solving 7-means
# Solving 8-means
# Solving 9-means
# Solving 10-means
# Solving 11-means
# Solving 12-means
# Solving 13-means
# Solving 14-means
# Solving 15-means
# Solving 16-means
# Solving 17-means
# Solving 18-means
# Solving 19-means
# Solving 20-means
# Solving 21-means
# Solving 22-means
# Solving 23-means
# Solving 24-means
# Solving 25-means
# Solving 26-means
# Solving 27-means
# Solving 28-means
# Solving 29-means
# Solving 30-means
# number of clusters= 13
# passed through here, flag=True
# number of clusters= 2

# %%
def uniforce_PCA_LAB(): 	
	global labels_to_feed
	global cluster_centers2
	global flag
	scaler = MinMaxScaler()
	d2_new_pca_lab_sum_scaled = scaler.fit_transform(pca_lab_spatial)
	uniforce = UniForCE(options)
	uniforce.fit(d2_new_pca_lab_sum_scaled)
	labels_to_feed = uniforce.labels_
	cluster_centers2 = calculate_centroids(d2_new_pca_lab_sum_scaled, labels_to_feed)
	flag = True
	
	_, unique_labels, pca_lab_xy_clusters = extract_labels_info(uniforce)
	uniforce_segmented_image = color_segmented_image(labels_to_feed, unique_labels, random_colors)
	
	return pca_lab_xy_clusters, uniforce_segmented_image

pca_lab_xy_clusters, uniforce_segmented_image = uniforce_PCA_LAB()

def uniforce_PCA_LAB_second_run():
    global flag
    scaler = MinMaxScaler()
    d2_new_pca_lab_sum_scaled = scaler.fit_transform(d2_new_pca_lab_sum)
    uniforce = UniForCE(options)
    uniforce.fit(d2_new_pca_lab_sum_scaled)

    labels, unique_labels, new_pca_lab_clusters = extract_labels_info(uniforce)
    new_uniforce_segmented_image = color_segmented_image(labels, unique_labels, random_colors)
    
    plt.imshow(new_uniforce_segmented_image)
    plt.show()
    flag = False
    return new_pca_lab_clusters, new_uniforce_segmented_image

new_pca_lab_clusters, new_uniforce_segmented_image = uniforce_PCA_LAB_second_run()
# Out:
# passed through here 1
# passed through here 1.1
# Solving 2-means
# Solving 3-means
# Solving 4-means
# Solving 5-means
# Solving 6-means
# Solving 7-means
# Solving 8-means
# Solving 9-means
# Solving 10-means
# Solving 11-means
# Solving 12-means
# Solving 13-means
# Solving 14-means
# Solving 15-means
# Solving 16-means
# Solving 17-means
# Solving 18-means
# Solving 19-means
# Solving 20-means
# Solving 21-means
# Solving 22-means
# Solving 23-means
# Solving 24-means
# Solving 25-means
# Solving 26-means
# Solving 27-means
# Solving 28-means
# Solving 29-means
# Solving 30-means
# number of clusters= 17
# passed through here, flag=True
# number of clusters= 6

# %%
def uniforce_PCA_LAB(): 
	scaler = MinMaxScaler()
	d2_new_pca_lab_sum_scaled = scaler.fit_transform(d2_new_pca_lab_sum)
	uniforce = UniForCE(options)
	uniforce.fit(d2_new_pca_lab_sum_scaled)
	sublabels = uniforce.sublabels_
	
	uniforce_aspp_lab_labels, unique_labels, pca_lab_clusters = extract_labels_info(uniforce)
	uniforce_segmented_image = color_segmented_image(uniforce_aspp_lab_labels, unique_labels, random_colors)

	plt.imshow(uniforce_segmented_image)
	plt.show()
	return pca_lab_clusters, uniforce_segmented_image, uniforce_aspp_lab_labels

pca_lab_clusters, uniforce_segmented_image, uniforce_aspp_lab_labels = uniforce_PCA_LAB()
# Out:
# passed through here 1
# passed through here 1.1
# Solving 2-means
# Solving 3-means
# Solving 4-means
# Solving 5-means
# Solving 6-means
# Solving 7-means
# Solving 8-means
# Solving 9-means
# Solving 10-means
# Solving 11-means
# Solving 12-means
# Solving 13-means
# Solving 14-means
# Solving 15-means
# Solving 16-means
# Solving 17-means
# Solving 18-means
# Solving 19-means
# Solving 20-means
# Solving 21-means
# Solving 22-means
# Solving 23-means
# Solving 24-means
# Solving 25-means
# Solving 26-means
# Solving 27-means
# Solving 28-means
# Solving 29-means
# Solving 30-means
# number of clusters= 12

# %%
# ASPP features and LAB values K-Means
def kmeans_PCA_LAB():
    km = KMeans(n_clusters=best_k, n_init="auto")
    km.fit(sampled_data)
    labels = km.predict(d2_new_pca_lab_sum)
    
    _, unique_labels, _ = extract_labels_info(km)
    kmeans_segmented_image = color_segmented_image(labels, unique_labels, random_colors)

    plt.imshow(kmeans_segmented_image)
    plt.show()
    return kmeans_segmented_image

kmeans_segmented_image = kmeans_PCA_LAB()
# Out:
# number of clusters= 3

# %%
# Uniforce on input rgb image
def uniforce_RGB():
    scaler = MinMaxScaler()
    rgb_pixels_scaled = scaler.fit_transform(rgb_pixels)
    uniforce = UniForCE(options)
    uniforce.fit(rgb_pixels_scaled)

    labels, unique_labels, rgb_clusters = extract_labels_info(uniforce)
    uniforce_rgb_image = color_segmented_image(labels, unique_labels, random_colors)

    plt.imshow(uniforce_rgb_image)
    plt.show()
    return rgb_clusters, uniforce_rgb_image

rgb_clusters, uniforce_rgb_image = uniforce_RGB()
# Out:
# passed through here 1
# passed through here 1.1
# Solving 2-means
# Solving 3-means
# Solving 4-means
# Solving 5-means
# Solving 6-means
# Solving 7-means
# Solving 8-means
# Solving 9-means
# Solving 10-means
# Solving 11-means
# Solving 12-means
# Solving 13-means
# Solving 14-means
# Solving 15-means
# Solving 16-means
# Solving 17-means
# Solving 18-means
# Solving 19-means
# Solving 20-means
# Solving 21-means
# Solving 22-means
# Solving 23-means
# Solving 24-means
# Solving 25-means
# Solving 26-means
# Solving 27-means
# Solving 28-means
# Solving 29-means
# Solving 30-means
# number of clusters= 8

# %%
# k-means on input rgb image
def kmeans_RGB():
    km = KMeans(n_clusters=best_k, n_init="auto")
    labels = km.fit_predict(rgb_pixels)

    labels, unique_labels, _ = extract_labels_info(km)
    kmeans_rgb_image = color_segmented_image(labels, unique_labels, random_colors)

    plt.imshow(kmeans_rgb_image)
    plt.show()
    return kmeans_rgb_image

kmeans_rgb_image = kmeans_RGB()
# Out:
# number of clusters= 3

# %%
#Clustering using [R G B X Y]
rgb_and_spatial_info = np.zeros((H*W, 5), np.uint16)
for y in range(H):
    for x in range(W):
        pixel_index = y * W + x
        rgb_and_spatial_info[pixel_index, 0:3] = rgb_image[y, x]
        rgb_and_spatial_info[pixel_index, 3] = x
        rgb_and_spatial_info[pixel_index, 4] = y

def uniforce_rgb_spatial():        
    scaler = MinMaxScaler()
    rgb_and_spatial_info_scaled = scaler.fit_transform(rgb_and_spatial_info)
    uniforce = UniForCE(options)
    uniforce.fit(rgb_and_spatial_info_scaled)
    
    labels, unique_labels, rgb_spatial_clusters = extract_labels_info(uniforce)
    uniforce_rgb_spatial_image = color_segmented_image(labels, unique_labels, random_colors)

    plt.imshow(uniforce_rgb_spatial_image)
    plt.show()
    return rgb_spatial_clusters, uniforce_rgb_spatial_image

rgb_spatial_clusters, uniforce_rgb_spatial_image = uniforce_rgb_spatial()
# Out:
# passed through here 1
# passed through here 1.1
# Solving 2-means
# Solving 3-means
# Solving 4-means
# Solving 5-means
# Solving 6-means
# Solving 7-means
# Solving 8-means
# Solving 9-means
# Solving 10-means
# Solving 11-means
# Solving 12-means
# Solving 13-means
# Solving 14-means
# Solving 15-means
# Solving 16-means
# Solving 17-means
# Solving 18-means
# Solving 19-means
# Solving 20-means
# Solving 21-means
# Solving 22-means
# Solving 23-means
# Solving 24-means
# Solving 25-means
# Solving 26-means
# Solving 27-means
# Solving 28-means
# Solving 29-means
# Solving 30-means
# number of clusters= 12

# %%
def uniforce_pca_lab_spatial():        
    scaler = MinMaxScaler()
    rgb_and_spatial_info_scaled = scaler.fit_transform(pca_lab_spatial)
    uniforce = UniForCE(options)
    uniforce.fit(rgb_and_spatial_info_scaled)

    labels, unique_labels, pca_lab_spatial_clusters = extract_labels_info(uniforce)
    uniforce_pca_lab_spatial_image = color_segmented_image(labels, unique_labels, random_colors)

    plt.imshow(uniforce_pca_lab_spatial_image)
    plt.show()
    return pca_lab_spatial_clusters, uniforce_pca_lab_spatial_image

pca_lab_spatial_clusters, uniforce_pca_lab_spatial_image = uniforce_pca_lab_spatial()
# Out:
# passed through here 1
# passed through here 1.1
# Solving 2-means
# Solving 3-means
# Solving 4-means
# Solving 5-means
# Solving 6-means
# Solving 7-means
# Solving 8-means
# Solving 9-means
# Solving 10-means
# Solving 11-means
# Solving 12-means
# Solving 13-means
# Solving 14-means
# Solving 15-means
# Solving 16-means
# Solving 17-means
# Solving 18-means
# Solving 19-means
# Solving 20-means
# Solving 21-means
# Solving 22-means
# Solving 23-means
# Solving 24-means
# Solving 25-means
# Solving 26-means
# Solving 27-means
# Solving 28-means
# Solving 29-means
# Solving 30-means
# number of clusters= 17

# %%
def display_images():
    _, axes = plt.subplots(3, 3, figsize=(20, 12))  
    
    axes[0, 0].set_title("Original Image")
    axes[0, 0].imshow(input_image)
    
    axes[0, 1].set_title("DeeplabV3 Image")
    axes[0, 1].imshow(deeplab_segmented_image)
    
    axes[0, 2].set_title("K-means ASPP features & LAB - {} clusters".format(best_k))
    axes[0, 2].imshow(kmeans_segmented_image)

    axes[1, 0].set_title("Uniforce [R G B X Y] - {} clusters".format(rgb_spatial_clusters))
    axes[1, 0].imshow(uniforce_rgb_spatial_image)

    axes[1, 1].set_title("NEW UniforceRGB segmentation - {} clusters".format(new_rgb_clusters))
    axes[1, 1].imshow(new_uniforce_rgb_image)
    
    axes[1, 2].set_title("Uniforce RGB segmentation - {} clusters".format(rgb_clusters))
    axes[1, 2].imshow(uniforce_rgb_image)

    axes[2, 0].set_title("Uniforce ASPP & LAB & XY - {} clusters".format(pca_lab_spatial_clusters))
    axes[2, 0].imshow(uniforce_pca_lab_spatial_image)

    axes[2, 1].set_title("NEW Uniforce ASPP features & LAB - {} clusters".format(new_pca_lab_clusters))
    axes[2, 1].imshow(new_uniforce_segmented_image)

    axes[2, 2].set_title("Uniforce ASPP & LAB - {} clusters".format(pca_lab_clusters))
    axes[2, 2].imshow(uniforce_segmented_image)

    plt.tight_layout()  # Adjust spacing between subplots
    plt.show()

display_images()

# %%
weights = np.ones_like(uniforce_aspp_lab_labels) / len(uniforce_aspp_lab_labels)
plt.hist(uniforce_aspp_lab_labels, weights=weights, bins=pca_lab_clusters)
# Out:
# (array([0.50776042, 0.06835937, 0.02523438, 0.08466146, 0.01507813,
#         0.06059896, 0.04476562, 0.09122396, 0.05213542, 0.02684896,
#         0.00528646, 0.01804688]),
#  array([ 0.        ,  0.91666667,  1.83333333,  2.75      ,  3.66666667,
#          4.58333333,  5.5       ,  6.41666667,  7.33333333,  8.25      ,
#          9.16666667, 10.08333333, 11.        ]),
#  <BarContainer object of 12 artists>)
